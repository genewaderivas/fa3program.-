# %% [markdown]
# <a href="https://colab.research.google.com/github/genewaderivas/fa3program.-/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("enter your name:")
age = int(input("enter your age:"))
course = input("enter your course:")

print("Student status:")
print(name)
print(age)
print(course)
# Out:
# enter your name:Gene
# enter your age:13
# enter your course:7
# Student status:
# Gene
# 13
# 7

# %%
grade = int(input("enter your grade:"))
if grade >= 75:
  print("Your grade is passing")
else:
  print("Your grade is failing")
# Out:
# enter your grade:84
# Your grade is passing

# %%
name = input("enter your name:")
score = int(input("enter your score:"))
if 90 <= score <= 100:
  print("A")
elif 80 <= score <= 89:
  print("B")
elif 70 <= score <= 79:
  print("C")
else:
  print("F")
# Out:
# enter your name:Gene
# enter your score:84
# B
